# %% [markdown]
# ## Harmonize ETL: HuBMAP
#
# Data Source: https://hubmapconsortium.github.io/ccf-asct-reporter/vis?selectedOrgans=All_Organs-v1.1,Blood-v1.1,Blood_Vasculature-v1.1,bone_marrow-v1.1,brain-v1.1,Eye-v1.0,Fallopian_Tube-v1.1,heart-v1.1,kidney-v1.1,Knee-v1.0,large_intestine-v1.1,Liver-v1.0,lung-v1.1,lymph_nodes-v1.1,Lymph_Vasculature-v1.0,Ovary-v1.0,Pancreas-v1.0,Peripheral_Nervous_System-v1.0,Prostate-v1.0,skin-v1.1,Small_Intestine-v1.0,spleen-v1.1,thymus-v1.1,Ureter-v1.0,Urinary_Bladder-v1.0,Uterus-v1.0&playground=false

# %%
import re
import sys
import pprint 
from datetime import date

# %% [markdown]
# ### Notebook Information

# %%
print('This notebook was run on:', date.today(), '\n Python version:', sys.version)
# Out:
# This notebook was run on: 2022-03-07
#  Python version: 3.9.1 (default, Feb  3 2021, 07:38:02)
# [Clang 12.0.0 (clang-1200.0.32.29)]

# %% [markdown]
# # Initialization

# %%
# Enter input file name
file_name = "Uterus.tsv"

# %%
read_file = open(file_name, "r")

# %%
def getList(dict):
    return dict.keys()

# %% [markdown]
# ### Create a dictionary where the keys are columns (CT/BGene) and values are rows

# %%
# Create dictionary where keys are columns and values are rows

def tsv_to_columns_row_dictionary(read_file):
    excel_dict = dict()
    key_list = list()
    for count, row in enumerate(read_file):
        temp = re.split(r'\t', row.strip("\n"))
        if count == 8:
            version = temp[1]
        if count == 10:
            for value in temp:
                excel_dict[value] = list()
                key_list.append(value)       
        if count > 10:
            for count, value in enumerate(temp):
                excel_dict[key_list[count]].append(value)
    return(excel_dict, key_list, version)

# %% [markdown]
# ## Output of column/row dictionary

# %%
excel_dict, key_list, version = tsv_to_columns_row_dictionary(read_file)

# %% [markdown]
# ### Create a list of cell types. Cell types are listed at the highest resolution base on ASCT+B Table

# %%
# Key_list is a list of column name. Ex. CT/2... 
# Add cell type to dictionary as key
def add_cell_type_to_list(excel_dict, key_list):
    cell_type_list = list()
    for index in range(0, len(excel_dict["AS/1"])):
        cell_type_list.append(list())
    
    for index in range(0, len(excel_dict["AS/1"])):
        for label in key_list:
            if "CT" in label and "LABEL" not in label and "ID" not in label and "NOTES" not in label:
                if excel_dict[label][index]:
                    cell_type_list[index] = (excel_dict[label][index])
    
    # Add unique identifier
    final_cell_type_list = list()
    for count, cell_type in enumerate(cell_type_list):
        final_cell_type = "{} ({})".format(cell_type, count)
        final_cell_type_list.append(final_cell_type)
    
    
    return(final_cell_type_list)

# %% [markdown]
# ### Cell Types List

# %%
cell_type_list = add_cell_type_to_list(excel_dict, key_list)
#pprint.pprint(cell_type_list)

# %% [markdown]
# ### Create a dictionary where the cell type is the key and the value is a gene marker

# %%
def add_gene_marker(cell_type_list, excel_dict):
    cell_type_gene_marker_dict = dict()
    
    for count, cell_type in enumerate(cell_type_list):
        cell_type_gene_marker_dict[cell_type] = excel_dict["All Gene Biomarkers"][count]
    
    return(cell_type_gene_marker_dict)


def add_gene_marker_no_all(cell_type_list, excel_dict):
    gene_list = list()
    for index in range(0, len(excel_dict["AS/1"])):
        gene_list.append(list())
    
    for index in range(0, len(excel_dict["AS/1"])):
        for label in key_list:
            if "BGene" in label and "LABEL" not in label and "ID" not in label:
                if excel_dict[label][index]:
                    if gene_list[index]:                       
                        gene_list[index].append(excel_dict[label][index])
                    else:
                        gene_list[index] = list()
                        gene_list[index].append(excel_dict[label][index])
                    
    cell_type_gene_marker_dict = dict()
    
    for count, cell_type in enumerate(cell_type_list):
        cell_type_gene_marker_dict[cell_type] = gene_list[count]
    
    return(cell_type_gene_marker_dict)

# %% [markdown]
# ## Output of cell type/gene marker dictionary

# %%
try:
    final_dict = add_gene_marker(cell_type_list, excel_dict)
except:
    final_dict = add_gene_marker_no_all(cell_type_list, excel_dict)
pprint.pprint(final_dict)
# Out:
# {'B cell (100)': [],
#  'B cell (121)': ['CD69', 'CCL5', 'MS4A1', 'CXCR4'],
#  'B cell (142)': ['CD69', 'CCL5', 'MS4A1', 'CXCR4'],
#  'B cell (16)': ['CD69', 'CCL5', 'MS4A1', 'CXCR4'],
#  'B cell (163)': [],
#  'B cell (184)': ['CD69', 'CCL5', 'MS4A1', 'CXCR4'],
#  'B cell (205)': ['CD69', 'CCL5', 'MS4A1', 'CXCR4'],
#  'B cell (226)': [],
#  'B cell (247)': ['CD69', 'CCL5', 'MS4A1', 'CXCR4'],
#  'B cell (37)': [],
#  'B cell (58)': ['CD69', 'CCL5', 'MS4A1', 'CXCR4'],
#  'B cell (79)': ['CD69', 'CCL5', 'MS4A1', 'CXCR4'],
#  'SOX9+ epithelial cell (110)': ['EPCAM', 'SOX9', 'MMP7'],
#  'SOX9+ epithelial cell (131)': ['EPCAM', 'SOX9', 'MMP7'],
#  'SOX9+ epithelial cell (152)': [],
#  'SOX9+ epithelial cell (173)': ['EPCAM', 'SOX9', 'MMP7'],
#  'SOX9+ epithelial cell (194)': ['EPCAM', 'SOX9', 'MMP7'],
#  'SOX9+ epithelial cell (215)': [],
#  'SOX9+ epithelial cell (236)': ['EPCAM', 'SOX9', 'MMP7'],
#  'SOX9+ epithelial cell (26)': [],
#  'SOX9+ epithelial cell (47)': ['EPCAM', 'SOX9', 'MMP7'],
#  'SOX9+ epithelial cell (5)': ['EPCAM', 'SOX9', 'MMP7'],
#  'SOX9+ epithelial cell (68)': ['EPCAM', 'SOX9', 'MMP7'],
#  'SOX9+ epithelial cell (89)': [],
#  'T cell (101)': [],
#  'T cell (122)': ['CD69', 'HMGB2', 'CD3G', 'IL7R', 'CXCR4', 'CCL5'],
#  'T cell (143)': ['CD69', 'HMGB2', 'CD3G', 'IL7R', 'CXCR4', 'CCL5'],
#  'T cell (164)': [],
#  'T cell (17)': ['CD69', 'HMGB2', 'CD3G', 'IL7R', 'CXCR4', 'CCL5'],
#  'T cell (185)': ['CD69', 'HMGB2', 'CD3G', 'IL7R', 'CXCR4', 'CCL5'],
#  'T cell (206)': ['CD69', 'HMGB2', 'CD3G', 'IL7R', 'CXCR4', 'CCL5'],
#  'T cell (227)': [],
#  'T cell (248)': ['CD69', 'HMGB2', 'CD3G', 'IL7R', 'CXCR4', 'CCL5'],
#  'T cell (38)': [],
#  'T cell (59)': ['CD69', 'HMGB2', 'CD3G', 'IL7R', 'CXCR4', 'CCL5'],
#  'T cell (80)': ['CD69', 'HMGB2', 'CD3G', 'IL7R', 'CXCR4', 'CCL5'],
#  '[] (1)': [],
#  '[] (106)': [],
#  '[] (127)': [],
#  '[] (148)': [],
#  '[] (169)': [],
#  '[] (190)': [],
#  '[] (211)': [],
#  '[] (22)': [],
#  '[] (232)': [],
#  '[] (251)': [],
#  '[] (252)': [],
#  '[] (253)': [],
#  '[] (254)': [],
#  '[] (255)': [],
#  '[] (256)': [],
#  '[] (257)': [],
#  '[] (258)': [],
#  '[] (259)': [],
#  '[] (260)': [],
#  '[] (261)': [],
#  '[] (262)': [],
#  '[] (263)': [],
#  '[] (264)': [],
#  '[] (265)': [],
#  '[] (266)': [],
#  '[] (267)': [],
#  '[] (268)': [],
#  '[] (269)': [],
#  '[] (270)': [],
#  '[] (271)': [],
#  '[] (272)': [],
#  '[] (273)': [],
#  '[] (274)': [],
#  '[] (275)': [],
#  '[] (276)': [],
#  '[] (277)': [],
#  '[] (278)': [],
#  '[] (279)': [],
#  '[] (280)': [],
#  '[] (281)': [],
#  '[] (282)': [],
#  '[] (283)': [],
#  '[] (284)': [],
#  '[] (285)': [],
#  '[] (286)': [],
#  '[] (287)': [],
#  '[] (288)': [],
#  '[] (289)': [],
#  '[] (290)': [],
#  '[] (291)': [],
#  '[] (292)': [],
#  '[] (293)': [],
#  '[] (294)': [],
#  '[] (295)': [],
#  '[] (296)': [],
#  '[] (297)': [],
#  '[] (298)': [],
#  '[] (299)': [],
#  '[] (300)': [],
#  '[] (301)': [],
#  '[] (302)': [],
#  '[] (303)': [],
#  '[] (304)': [],
#  '[] (305)': [],
#  '[] (306)': [],
#  '[] (307)': [],
#  '[] (308)': [],
#  '[] (309)': [],
#  '[] (310)': [],
#  '[] (311)': [],
#  '[] (312)': [],
#  '[] (313)': [],
#  '[] (314)': [],
#  '[] (316)': [],
#  '[] (317)': [],
#  '[] (318)': [],
#  '[] (319)': [],
#  '[] (320)': [],
#  '[] (321)': [],
#  '[] (322)': [],
#  '[] (323)': [],
#  '[] (324)': [],
#  '[] (325)': [],
#  '[] (326)': [],
#  '[] (327)': [],
#  '[] (328)': [],
#  '[] (329)': [],
#  '[] (330)': [],
#  '[] (331)': [],
#  '[] (332)': [],
#  '[] (333)': [],
#  '[] (334)': [],
#  '[] (335)': [],
#  '[] (336)': [],
#  '[] (337)': [],
#  '[] (338)': [],
#  '[] (339)': [],
#  '[] (340)': [],
#  '[] (341)': [],
#  '[] (342)': [],
#  '[] (343)': [],
#  '[] (344)': [],
#  '[] (345)': [],
#  '[] (346)': [],
#  '[] (347)': [],
#  '[] (348)': [],
#  '[] (349)': [],
#  '[] (350)': [],
#  '[] (351)': [],
#  '[] (352)': [],
#  '[] (353)': [],
#  '[] (354)': [],
#  '[] (355)': [],
#  '[] (356)': [],
#  '[] (357)': [],
#  '[] (358)': [],
#  '[] (359)': [],
#  '[] (360)': [],
#  '[] (361)': [],
#  '[] (362)': [],
#  '[] (363)': [],
#  '[] (364)': [],
#  '[] (365)': [],
#  '[] (366)': [],
#  '[] (367)': [],
#  '[] (368)': [],
#  '[] (369)': [],
#  '[] (370)': [],
#  '[] (371)': [],
#  '[] (372)': [],
#  '[] (373)': [],
#  '[] (374)': [],
#  '[] (375)': [],
#  '[] (376)': [],
#  '[] (379)': [],
#  '[] (380)': [],
#  '[] (381)': [],
#  '[] (382)': [],
#  '[] (383)': [],
#  '[] (384)': [],
#  '[] (385)': [],
#  '[] (386)': [],
#  '[] (387)': [],
#  '[] (388)': [],
#  '[] (389)': [],
#  '[] (390)': [],
#  '[] (391)': [],
#  '[] (392)': [],
#  '[] (393)': [],
#  '[] (394)': [],
#  '[] (395)': [],
#  '[] (396)': [],
#  '[] (43)': [],
#  '[] (64)': [],
#  '[] (85)': [],
#  'ciliated epithelial cell (111)': ['EPCAM', 'PIFO', 'TPPP3', 'FOXJ1'],
#  'ciliated epithelial cell (132)': ['EPCAM', 'PIFO', 'TPPP3', 'FOXJ1'],
#  'ciliated epithelial cell (153)': [],
#  'ciliated epithelial cell (174)': ['EPCAM', 'PIFO', 'TPPP3', 'FOXJ1'],
#  'ciliated epithelial cell (195)': ['EPCAM', 'PIFO', 'TPPP3', 'FOXJ1'],
#  'ciliated epithelial cell (216)': [],
#  'ciliated epithelial cell (237)': ['EPCAM', 'PIFO', 'TPPP3', 'FOXJ1'],
#  'ciliated epithelial cell (27)': [],
#  'ciliated epithelial cell (48)': ['EPCAM', 'PIFO', 'TPPP3', 'FOXJ1'],
#  'ciliated epithelial cell (6)': ['EPCAM', 'PIFO', 'TPPP3', 'FOXJ1'],
#  'ciliated epithelial cell (69)': ['EPCAM', 'PIFO', 'TPPP3', 'FOXJ1'],
#  'ciliated epithelial cell (90)': [],
#  'columnar cell of endocervix (377)': [],
#  'endocervical epithelial cell (378)': [],
#  'endothelial cell (104)': [],
#  'endothelial cell (109)': [],
#  'endothelial cell (125)': ['CD34', 'SEMA3G', 'ACKR1'],
#  'endothelial cell (130)': [],
#  'endothelial cell (146)': ['CD34', 'SEMA3G', 'ACKR1'],
#  'endothelial cell (151)': [],
#  'endothelial cell (167)': [],
#  'endothelial cell (172)': [],
#  'endothelial cell (188)': ['CD34', 'SEMA3G', 'ACKR1'],
#  'endothelial cell (193)': [],
#  'endothelial cell (20)': ['CD34', 'SEMA3G', 'ACKR1'],
#  'endothelial cell (209)': ['CD34', 'SEMA3G', 'ACKR1'],
#  'endothelial cell (214)': [],
#  'endothelial cell (230)': [],
#  'endothelial cell (235)': [],
#  'endothelial cell (25)': [],
#  'endothelial cell (315)': ['CD34', 'SEMA3G', 'ACKR1'],
#  'endothelial cell (4)': [],
#  'endothelial cell (41)': [],
#  'endothelial cell (46)': [],
#  'endothelial cell (62)': ['CD34', 'SEMA3G', 'ACKR1'],
#  'endothelial cell (67)': [],
#  'endothelial cell (83)': ['CD34', 'SEMA3G', 'ACKR1'],
#  'endothelial cell (88)': [],
#  'glandular epithelial cell (112)': ['EPCAM', 'SCGB2A2', 'PAEP', 'CXCL8'],
#  'glandular epithelial cell (133)': ['EPCAM', 'SCGB2A2', 'PAEP', 'CXCL8'],
#  'glandular epithelial cell (154)': [],
#  'glandular epithelial cell (175)': ['EPCAM', 'SCGB2A2', 'PAEP', 'CXCL8'],
#  'glandular epithelial cell (196)': ['EPCAM', 'SCGB2A2', 'PAEP', 'CXCL8'],
#  'glandular epithelial cell (217)': [],
#  'glandular epithelial cell (238)': ['EPCAM', 'SCGB2A2', 'PAEP', 'CXCL8'],
#  'glandular epithelial cell (28)': [],
#  'glandular epithelial cell (49)': ['EPCAM', 'SCGB2A2', 'PAEP', 'CXCL8'],
#  'glandular epithelial cell (7)': ['EPCAM', 'SCGB2A2', 'PAEP', 'CXCL8'],
#  'glandular epithelial cell (70)': ['EPCAM', 'SCGB2A2', 'PAEP', 'CXCL8'],
#  'glandular epithelial cell (91)': [],
#  'innate lymphoid cell (102)': [],
#  'innate lymphoid cell (123)': ['CD69',
#                                 'KIT',
#                                 'IL7R',
#                                 'CXCR4',
#                                 'CCL5',
#                                 'SPINK2'],
#  'innate lymphoid cell (144)': ['CD69',
#                                 'KIT',
#                                 'IL7R',
#                                 'CXCR4',
#                                 'CCL5',
#                                 'SPINK2'],
#  'innate lymphoid cell (165)': [],
#  'innate lymphoid cell (18)': ['CD69',
#                                'KIT',
#                                'IL7R',
#                                'CXCR4',
#                                'CCL5',
#                                'SPINK2'],
#  'innate lymphoid cell (186)': ['CD69',
#                                 'KIT',
#                                 'IL7R',
#                                 'CXCR4',
#                                 'CCL5',
#                                 'SPINK2'],
#  'innate lymphoid cell (207)': ['CD69',
#                                 'KIT',
#                                 'IL7R',
#                                 'CXCR4',
#                                 'CCL5',
#                                 'SPINK2'],
#  'innate lymphoid cell (228)': [],
#  'innate lymphoid cell (249)': ['CD69',
#                                 'KIT',
#                                 'IL7R',
#                                 'CXCR4',
#                                 'CCL5',
#                                 'SPINK2'],
#  'innate lymphoid cell (39)': [],
#  'innate lymphoid cell (60)': ['CD69',
#                                'KIT',
#                                'IL7R',
#                                'CXCR4',
#                                'CCL5',
#                                'SPINK2'],
#  'innate lymphoid cell (81)': ['CD69',
#                                'KIT',
#                                'IL7R',
#                                'CXCR4',
#                                'CCL5',
#                                'SPINK2'],
#  'luminal epithelial cell (113)': ['EPCAM', 'LGR5', 'PTGS1'],
#  'luminal epithelial cell (134)': ['EPCAM', 'LGR5', 'PTGS1'],
#  'luminal epithelial cell (155)': [],
#  'luminal epithelial cell (176)': ['EPCAM', 'LGR5', 'PTGS1'],
#  'luminal epithelial cell (197)': ['EPCAM', 'LGR5', 'PTGS1'],
#  'luminal epithelial cell (218)': [],
#  'luminal epithelial cell (239)': ['EPCAM', 'LGR5', 'PTGS1'],
#  'luminal epithelial cell (29)': [],
#  'luminal epithelial cell (50)': ['EPCAM', 'LGR5', 'PTGS1'],
#  'luminal epithelial cell (71)': ['EPCAM', 'LGR5', 'PTGS1'],
#  'luminal epithelial cell (8)': ['EPCAM', 'LGR5', 'PTGS1'],
#  'luminal epithelial cell (92)': [],
#  'lymphocyte (118)': ['PTPRC', 'NCAM1'],
#  'lymphocyte (13)': ['PTPRC', 'NCAM1'],
#  'lymphocyte (139)': ['PTPRC', 'NCAM1'],
#  'lymphocyte (160)': [],
#  'lymphocyte (181)': ['PTPRC', 'NCAM1'],
#  'lymphocyte (202)': ['PTPRC', 'NCAM1'],
#  'lymphocyte (223)': [],
#  'lymphocyte (244)': ['PTPRC', 'NCAM1'],
#  'lymphocyte (34)': [],
#  'lymphocyte (55)': ['PTPRC', 'NCAM1'],
#  'lymphocyte (76)': ['PTPRC', 'NCAM1'],
#  'lymphocyte (97)': [],
#  'macrophage (117)': ['CD68', 'CD14', 'CSF1R', 'IL1B', 'SEPP1'],
#  'macrophage (12)': ['CD68', 'CD14', 'CSF1R', 'IL1B', 'SEPP1'],
#  'macrophage (138)': ['CD68', 'CD14', 'CSF1R', 'IL1B', 'SEPP1'],
#  'macrophage (159)': [],
#  'macrophage (180)': ['CD68', 'CD14', 'CSF1R', 'IL1B', 'SEPP1'],
#  'macrophage (201)': ['CD68', 'CD14', 'CSF1R', 'IL1B', 'SEPP1'],
#  'macrophage (222)': [],
#  'macrophage (243)': ['CD68', 'CD14', 'CSF1R', 'IL1B', 'SEPP1'],
#  'macrophage (33)': [],
#  'macrophage (54)': ['CD68', 'CD14', 'CSF1R', 'IL1B', 'SEPP1'],
#  'macrophage (75)': ['CD68', 'CD14', 'CSF1R', 'IL1B', 'SEPP1'],
#  'macrophage (96)': [],
#  'mast cell (103)': [],
#  'mast cell (124)': ['CD69', 'MS4A2', 'KIT', 'CSF1'],
#  'mast cell (145)': ['CD69', 'MS4A2', 'KIT', 'CSF1'],
#  'mast cell (166)': [],
#  'mast cell (187)': ['CD69', 'MS4A2', 'KIT', 'CSF1'],
#  'mast cell (19)': ['CD69', 'MS4A2', 'KIT', 'CSF1'],
#  'mast cell (208)': ['CD69', 'MS4A2', 'KIT', 'CSF1'],
#  'mast cell (229)': [],
#  'mast cell (250)': ['CD69', 'MS4A2', 'KIT', 'CSF1'],
#  'mast cell (40)': [],
#  'mast cell (61)': ['CD69', 'MS4A2', 'KIT', 'CSF1'],
#  'mast cell (82)': ['CD69', 'MS4A2', 'KIT', 'CSF1'],
#  'mesothelium of the uterine serosa (0)': [],
#  'mesothelium of the uterine serosa (105)': [],
#  'mesothelium of the uterine serosa (126)': [],
#  'mesothelium of the uterine serosa (147)': [],
#  'mesothelium of the uterine serosa (168)': [],
#  'mesothelium of the uterine serosa (189)': [],
#  'mesothelium of the uterine serosa (21)': [],
#  'mesothelium of the uterine serosa (210)': [],
#  'mesothelium of the uterine serosa (231)': [],
#  'mesothelium of the uterine serosa (42)': [],
#  'mesothelium of the uterine serosa (63)': [],
#  'mesothelium of the uterine serosa (84)': [],
#  'perivascular support cell (11)': ['ACTA2', 'MYH11'],
#  'perivascular support cell (116)': ['ACTA2', 'MYH11'],
#  'perivascular support cell (137)': ['ACTA2', 'MYH11'],
#  'perivascular support cell (158)': [],
#  'perivascular support cell (179)': ['ACTA2', 'MYH11'],
#  'perivascular support cell (200)': ['ACTA2', 'MYH11'],
#  'perivascular support cell (221)': [],
#  'perivascular support cell (242)': ['ACTA2', 'MYH11'],
#  'perivascular support cell (32)': [],
#  'perivascular support cell (53)': ['ACTA2', 'MYH11'],
#  'perivascular support cell (74)': ['ACTA2', 'MYH11'],
#  'perivascular support cell (95)': [],
#  'stromal cell (114)': ['IGF1', 'PCOLCE', 'MMP11', 'OGN'],
#  'stromal cell (135)': ['IGF1', 'PCOLCE', 'MMP11', 'OGN'],
#  'stromal cell (156)': [],
#  'stromal cell (177)': ['IGF1', 'PCOLCE', 'MMP11', 'OGN'],
#  'stromal cell (198)': ['IGF1', 'PCOLCE', 'MMP11', 'OGN'],
#  'stromal cell (219)': [],
#  'stromal cell (240)': ['IGF1', 'PCOLCE', 'MMP11', 'OGN'],
#  'stromal cell (30)': [],
#  'stromal cell (51)': ['IGF1', 'PCOLCE', 'MMP11', 'OGN'],
#  'stromal cell (72)': ['IGF1', 'PCOLCE', 'MMP11', 'OGN'],
#  'stromal cell (9)': ['IGF1', 'PCOLCE', 'MMP11', 'OGN'],
#  'stromal cell (93)': [],
#  'uterine dendritic cells (120)': ['IL1B', 'CD68'],
#  'uterine dendritic cells (141)': ['IL1B', 'CD68'],
#  'uterine dendritic cells (15)': ['IL1B', 'CD68'],
#  'uterine dendritic cells (162)': [],
#  'uterine dendritic cells (183)': ['IL1B', 'CD68'],
#  'uterine dendritic cells (204)': ['IL1B', 'CD68'],
#  'uterine dendritic cells (225)': [],
#  'uterine dendritic cells (246)': ['IL1B', 'CD68'],
#  'uterine dendritic cells (36)': [],
#  'uterine dendritic cells (57)': ['IL1B', 'CD68'],
#  'uterine dendritic cells (78)': ['IL1B', 'CD68'],
#  'uterine dendritic cells (99)': [],
#  'uterine natural killer cell (119)': ['CD69', 'HMGB2', 'NCAM1', 'CCL5'],
#  'uterine natural killer cell (14)': ['CD69', 'HMGB2', 'NCAM1', 'CCL5'],
#  'uterine natural killer cell (140)': ['CD69', 'HMGB2', 'NCAM1', 'CCL5'],
#  'uterine natural killer cell (161)': [],
#  'uterine natural killer cell (182)': ['CD69', 'HMGB2', 'NCAM1', 'CCL5'],
#  'uterine natural killer cell (203)': ['CD69', 'HMGB2', 'NCAM1', 'CCL5'],
#  'uterine natural killer cell (224)': [],
#  'uterine natural killer cell (245)': ['CD69', 'HMGB2', 'NCAM1', 'CCL5'],
#  'uterine natural killer cell (35)': [],
#  'uterine natural killer cell (56)': ['CD69', 'HMGB2', 'NCAM1', 'CCL5'],
#  'uterine natural killer cell (77)': ['CD69', 'HMGB2', 'NCAM1', 'CCL5'],
#  'uterine natural killer cell (98)': [],
#  'uterine smooth muscle cell (10)': ['ACTA2', 'MYH11', 'ACTG2'],
#  'uterine smooth muscle cell (107)': [],
#  'uterine smooth muscle cell (108)': [],
#  'uterine smooth muscle cell (115)': ['ACTA2', 'MYH11', 'ACTG2'],
#  'uterine smooth muscle cell (128)': [],
#  'uterine smooth muscle cell (129)': [],
#  'uterine smooth muscle cell (136)': ['ACTA2', 'MYH11', 'ACTG2'],
#  'uterine smooth muscle cell (149)': [],
#  'uterine smooth muscle cell (150)': [],
#  'uterine smooth muscle cell (157)': [],
#  'uterine smooth muscle cell (170)': [],
#  'uterine smooth muscle cell (171)': [],
#  'uterine smooth muscle cell (178)': ['ACTA2', 'MYH11', 'ACTG2'],
#  'uterine smooth muscle cell (191)': [],
#  'uterine smooth muscle cell (192)': [],
#  'uterine smooth muscle cell (199)': ['ACTA2', 'MYH11', 'ACTG2'],
#  'uterine smooth muscle cell (2)': [],
#  'uterine smooth muscle cell (212)': [],
#  'uterine smooth muscle cell (213)': [],
#  'uterine smooth muscle cell (220)': [],
#  'uterine smooth muscle cell (23)': [],
#  'uterine smooth muscle cell (233)': [],
#  'uterine smooth muscle cell (234)': [],
#  'uterine smooth muscle cell (24)': [],
#  'uterine smooth muscle cell (241)': ['ACTA2', 'MYH11', 'ACTG2'],
#  'uterine smooth muscle cell (3)': [],
#  'uterine smooth muscle cell (31)': [],
#  'uterine smooth muscle cell (44)': [],
#  'uterine smooth muscle cell (45)': [],
#  'uterine smooth muscle cell (52)': ['ACTA2', 'MYH11', 'ACTG2'],
#  'uterine smooth muscle cell (65)': [],
#  'uterine smooth muscle cell (66)': [],
#  'uterine smooth muscle cell (73)': ['ACTA2', 'MYH11', 'ACTG2'],
#  'uterine smooth muscle cell (86)': [],
#  'uterine smooth muscle cell (87)': [],
#  'uterine smooth muscle cell (94)': []}

# %%
output_filename = "{}_GMT_{}.tsv".format(file_name[:-4], version)
fh = open(output_filename , "w")
for key, value in final_dict.items():
    if "[" in key and not value:
        continue
    elif value and type(value) == list:
        fh.write("{}\t{}\n".format(key.strip('\t'), ', '.join(value).strip('\t')))
    elif value:
        fh.write("{}\t{}\n".format(key, value))
    else:
        fh.write("{}\n".format(key))

# %% [markdown]
# ### Generate url to download ASCT+B Table

# %%
sheetID_dict = {"Blood": "1ZYcSWnFHmzR9XKy_002f_oA4PfzokiW4IxkaZZOusvg",
                "Blood_Vascular": "1IlELzPwpWoHUcDAmNBWofXfislAaF_oR8yVpwy-zl18",
                "Bone_Marrow": "1tnqtCAWSA6atiUBUOOjAHdOrjDw_fsIoCd5RkAmw310",
                "Brain": "1TiwW1NZJ5kdCzJ4zwCpY3Gzv3WE5WUoBDWIAkU5gXd0",
                "Breast": "1Ac7C4dX7eYSMyR75AA2uVY9ZgNGOZZgbqgR8wmp-wdk",
                "Eye": "1u7IbxnPABRpYL5rFxOba8cmlvG1yGp-dwD3TV3V26K4",
                "Fallopian_Tube": "16tAvAmjwKwbq5SDz7UZ-T1N_KUHRGqPDbMqffFuInMI",
                "Heart": "1UhEZpDxQLCJLLx0gnWYDMQP8M-dwjZo_vIyPfjBCcVM",
                "Kidney": "1PgjYp4MEWANfbxGIxFsJ9vkfEU90MP-v3p5oVlH8U-E",
                "Knee": "1QidDho8DxBYjsxaqApiIZA__Z7aWnB61KvC422g2kx8",
                "Large_Intestine": "1vU6mQmnzAAxctbNYPoFxJ8NvbUql8pbipsGdt7YCOQQ",
                "Liver": "1tPDKw_znxqWhZYPTeVN4AN2_F4-JecsdeUgp2lj4P8g",
                "Lung": "1tK916JyG5ZSXW_cXfsyZnzXfjyoN-8B2GXLbYD6_vF0",
                "Lymph_Node": "1aK9gJ2_kMb2B8zrQgScDgxpEWAcCs7kl-gnQGwV3LHM",
                "Lymph_Vasculature": "1SILRNUI71BEVWl1fpsi_32DSuSA-bAPgXv5pTfKnrOE",
                "Ovary": "1FE2XufrruExUWqcai3XRFqtMjeEdzoLKJ-YNa-nRZ1M",
                "Pancreas": "1CIWqIygz2OzxMECIvhudFN14Kt7-JFUBLpzn5uuH5Xs",
                "Peripheral_Nervous_System": "1KifiEDn3PpJ8pjz9_ka4TWkT085wLIzIQP5NKSvb2Ac",
                "Placenta": "1TqatRIsZZ5QwvWdz6H4Un-sukbzSd21_x41Gqnn5UEY",
                "Prostate": "1_O5yXOesG93dobMHRSIvVAt9xj7mDnEAYdRJcHYJ84U",
                "Skin": "1Pmi3g26vhbg9HU6GDpIvxKbIP985JM-5eytOHxJUdZs",
                "Small_Intestine": "1Xlds8FzZ8ecmy3cxYJt1ijQC9FifamZRZ5KzH4Yt-MQ",
                "Spleen": "1HL7aHx5A2KOa1KsJ0PIagqxdshVavFIEJZP6_YDtUww",
                "Spinal_Cord": "1tK916JyG5ZSXW_cXfsyZnzXfjyoN-8B2GXLbYD6_vF0",
                "Thymus": "1nSiz2yFDMJSqIXbnAP_EXIQZfN6ZflOs-WBdZ6LVhUY",
                "Ureter": "1tK916JyG5ZSXW_cXfsyZnzXfjyoN-8B2GXLbYD6_vF0",
                "Urinary_Bladder": "1ohOG5jMf9d9eqjbVK6_u3CvgfG3wcLfs_pxB2838wOo",
                "Uterus": "1yEcbJMrUIzJY-4JNtF1Y_eUpAQsgKF6DX2-5Z3UXBeE"
               }

# %%
gidID_dict = {"Blood": "360436225",
              "Blood_Vascular": "997949803",
              "Bone_Marrow": "771476671",
              "Brain": "2056967441",
              "Breast": "928286522",
              "Eye": "44026578",
              "Fallopian_Tube": "1739942440",
              "Heart": "1759721736",
              "Kidney": "949267305",
              "Knee": "1824489301",
              "Large_Intestine": "2043181688",
              "Liver": "1460762432",
              "Lung": "1824552484",
              "Lymph_Node": "1223566381",
              "Lymph_Vasculature": "1700987638",
              "Ovary": "1997082517",
              "Pancreas": "801179416",
              "Peripheral_Nervous_System": "714133140",
              "Placenta": "231591207",
              "Prostate": "1757780481",
              "Skin": "269383687",
              "Small_Intestine": "1762589435",
              "Spleen": "69626346",
              "Spinal_Cord": "1106564583",
              "Thymus": "863370556",
              "Ureter": "1106564583",
              "Urinary_Bladder": "1342577957",
              "Uterus": "1434605386"
             }

# %%
version_dict = {"Blood": "v1.1",
                "Blood_Vascular": "v1.1",
                "Bone_Marrow": "v1.1",
                "Brain": "v1.1",
                "Breast": "v1.0",
                "Eye": "v1.0",
                "Fallopian_Tube": "v1.0",
                "Heart": "v1.1",
                "Kidney": "v1.1",
                "Knee": "v1.0",
                "Large_Intestine": "v1.1",
                "Liver": "v1.0",
                "Lung": "v1.1",
                "Lymph_Node": "v1.1",
                "Lymph_Vasculature": "v1.0",
                "Ovary": "v1.0",
                "Pancreas": "v1.0",
                "Peripheral_Nervous_System": "v1.0",
                "Placenta": "v1.0",
                "Prostate": "v1.0",
                "Skin": "v1.1",
                "Small_Intestine": "v1.0",
                "Spleen": "v1.1",
                "Spinal_Cord": "v1.0",
                "Thymus": "v1.1",
                "Ureter": "v1.0",
                "Urinary_Bladder": "v1.0",
                "Uterus": "v1.0"
               }

# %% [markdown]
# ### Write ASCT+B URL to text file

# %%
organ_list = [organ for organ, id in sheetID_dict.items()]
url_list = list()

read_url = open("url.txt", "w")
for organ in organ_list:  
    url = "https://docs.google.com/spreadsheets/d/{}/edit#gid={}".format(sheetID_dict[organ], gidID_dict[organ])
    url_list.append(url)
    read_url.write("Organ: {} - {}\n".format(organ, url))

#pprint.pprint(url_list)
